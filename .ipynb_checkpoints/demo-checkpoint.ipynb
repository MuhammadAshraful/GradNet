# %%
 # !pip install graphviz
from graphviz import Digraph
from IPython.display import display, SVG
from GradNet.engine import Value
from GradNet.nn import MLP, Neuron, Layer
# Out:
# Requirement already satisfied: graphviz in c:\users\96898\anaconda3\lib\site-packages (0.20.3)

# %%
def trace(root):
    nodes, edges = set(), set()
    
    def build(v):
        if v not in nodes:
            nodes.add(v)
            for child in v.inputs:
                edges.add((child, v))
                build(child)
    
    build(root)
    return nodes, edges

def draw_dot(root, format='svg', rankdir='LR'):
    nodes, edges = trace(root)
    dot = Digraph(format=format, graph_attr={'rankdir': rankdir})

    # Add nodes
    for n in nodes:
        dot.node(name=str(id(n)), label="{data %s | gradient=%.4f}" % (n.num, n.gradient), shape='record')
        if n.operation:  # If the node is a result of an operation
            dot.node(name=str(id(n)) + n.operation, label=n.operation)
            dot.edge(str(id(n)) + n.operation, str(id(n)))

    # Add edges
    for n1, n2 in edges:
        dot.edge(str(id(n1)), str(id(n2)) + n2.operation)
    
    return dot

# %%
# Forward Pass

inputs = [Value(0.5), Value(-0.3), Value(0.8)]

mlp1 = MLP(3, 3, 1)
mlp2 = MLP(3, 4, 1)
mlp3 = MLP(4, 1, 1)




inputs = mlp1.forward(inputs)
print("MLP 1 outputs", inputs, "\n")

inputs = mlp2.forward(inputs)
print("MLP 2 outputs", inputs, "\n")

inputs = mlp3.forward(inputs)
print("MLP 3 outputs", inputs, "\n")
# Out:
# inputs =  [Value(num=0.5), Value(num=-0.3), Value(num=0.8)]
# weights =  [-0.5067836203890863, 0.9971624445641505, 0.19813295758782123]
# bias =  -0.6643496423093809
# weighted_sum =  Value(num=-1.058383819802912)
#
#
# inputs =  [Value(num=0.5), Value(num=-0.3), Value(num=0.8)]
# weights =  [-0.431596296167682, -0.9978862431031283, 0.2822632420105071]
# bias =  -0.9827518019662747
# weighted_sum =  Value(num=-0.6733734835107714)
#
#
# inputs =  [Value(num=0.5), Value(num=-0.3), Value(num=0.8)]
# weights =  [-0.39650133377614294, 0.05390022833935593, 0.6086645809824014]
# bias =  0.8781478089972898
# weighted_sum =  Value(num=1.1506587383933327)
#
#
# MLP 1 outputs [Value(num=-1.058383819802912), Value(num=-0.6733734835107714), Value(num=1.1506587383933327)]
#
# inputs =  [Value(num=-1.058383819802912), Value(num=-0.6733734835107714), Value(num=1.1506587383933327)]
# weights =  [0.8037400061627866, 0.8058065663740552, 0.610700255710277]
# bias =  -0.7438220413875365
# weighted_sum =  Value(num=-1.434388648101601)
#
#
# inputs =  [Value(num=-1.058383819802912), Value(num=-0.6733734835107714), Value(num=1.1506587383933327)]
# weights =  [0.8721134779731956, -0.3608370923040016, 0.019692347587514147]
# bias =  0.06463926704033907
# weighted_sum =  Value(num=-0.5927542254228391)
#
#
# inputs =  [Value(num=-1.058383819802912), Value(num=-0.6733734835107714), Value(num=1.1506587383933327)]
# weights =  [-0.5675227646099543, 0.490486973670083, 0.08607476571842643]
# bias =  -0.37539976328634816
# weighted_sum =  Value(num=-0.005981092601169358)
#
#
# inputs =  [Value(num=-1.058383819802912), Value(num=-0.6733734835107714), Value(num=1.1506587383933327)]
# weights =  [0.7149046631575073, -0.8152564494494428, -0.4733277342665323]
# bias =  0.4724282401833906
# weighted_sum =  Value(num=-0.27988190624147447)
#
#
# MLP 2 outputs [Value(num=-1.434388648101601), Value(num=-0.5927542254228391), Value(num=-0.005981092601169358), Value(num=-0.27988190624147447)]
#
# inputs =  [Value(num=-1.434388648101601), Value(num=-0.5927542254228391), Value(num=-0.005981092601169358), Value(num=-0.27988190624147447)]
# weights =  [-0.3220037553699693, 0.34401734704639786, -0.39019396432140807, 0.09085473748815698]
# bias =  -0.6562667226077885
# weighted_sum =  Value(num=-0.42140073822575763)
#
#
# MLP 3 outputs [Value(num=-0.42140073822575763)]

# %%
# Reset gradients for all output neurons (once before the backward pass)
for neuron in inputs: 
    neuron.reset_grad()

# %%
# Backward Pass

for neuron in inputs:
    neuron.gradient = 1.0
    neuron.backward()
# Out:
# Addition
# -----------------
# self.num =  0.2348659843820309
# other.num =  -0.6562667226077885
# out.num =  -0.42140073822575763
# self.gradient before =  0.0
# self.gradient after =  1.0
# out.gradient =  1.0
#
#
# Addition
# -----------------
# self.num =  0.26029458150128504
# other.num =  -0.025428597119254128
# out.num =  0.2348659843820309
# self.gradient before =  0.0
# self.gradient after =  1.0
# out.gradient =  1.0
#
#
# Addition
# -----------------
# self.num =  0.2579607952682613
# other.num =  0.002333786233023714
# out.num =  0.26029458150128504
# self.gradient before =  0.0
# self.gradient after =  1.0
# out.gradient =  1.0
#
#
# Addition
# -----------------
# self.num =  0.4618785313487689
# other.num =  -0.2039177360805076
# out.num =  0.2579607952682613
# self.gradient before =  0.0
# self.gradient after =  1.0
# out.gradient =  1.0
#
#
# Addition
# -----------------
# self.num =  0.4618785313487689
# other.num =  0
# out.num =  0.4618785313487689
# self.gradient before =  0.0
# self.gradient after =  1.0
# out.gradient =  1.0
#
#
# Multiplication
# -----------------
# self.num =  -1.434388648101601
# other.num =  -0.3220037553699693
# out.num =  0.4618785313487689
# self.gradient before =  0.0
# self.gradient after =  -0.3220037553699693
# out.gradient =  1.0
#
#
# Addition
# -----------------
# self.num =  -0.6905666067140644
# other.num =  -0.7438220413875365
# out.num =  -1.434388648101601
# self.gradient before =  0.0
# self.gradient after =  -0.3220037553699693
# out.gradient =  -0.3220037553699693
#
#
# Addition
# -----------------
# self.num =  -1.3932741924861374
# other.num =  0.7027075857720729
# out.num =  -0.6905666067140644
# self.gradient before =  0.0
# self.gradient after =  -0.3220037553699693
# out.gradient =  -0.3220037553699693
#
#
# Addition
# -----------------
# self.num =  -0.8506654178509861
# other.num =  -0.5426087746351512
# out.num =  -1.3932741924861374
# self.gradient before =  0.0
# self.gradient after =  -0.3220037553699693
# out.gradient =  -0.3220037553699693
#
#
# Addition
# -----------------
# self.num =  -0.8506654178509861
# other.num =  0
# out.num =  -0.8506654178509861
# self.gradient before =  0.0
# self.gradient after =  -0.3220037553699693
# out.gradient =  -0.3220037553699693
#
#
# Multiplication
# -----------------
# self.num =  -1.058383819802912
# other.num =  0.8037400061627866
# out.num =  -0.8506654178509861
# self.gradient before =  0.0
# self.gradient after =  -0.25880730032549953
# out.gradient =  -0.3220037553699693
#
#
# Addition
# -----------------
# self.num =  -0.3940341774935312
# other.num =  -0.6643496423093809
# out.num =  -1.058383819802912
# self.gradient before =  0.0
# self.gradient after =  -0.25880730032549953
# out.gradient =  -0.25880730032549953
#
#
# Addition
# -----------------
# self.num =  -0.5525405435637882
# other.num =  0.158506366070257
# out.num =  -0.3940341774935312
# self.gradient before =  0.0
# self.gradient after =  -0.25880730032549953
# out.gradient =  -0.25880730032549953
#
#
# Addition
# -----------------
# self.num =  -0.25339181019454315
# other.num =  -0.29914873336924513
# out.num =  -0.5525405435637882
# self.gradient before =  0.0
# self.gradient after =  -0.25880730032549953
# out.gradient =  -0.25880730032549953
#
#
# Addition
# -----------------
# self.num =  -0.25339181019454315
# other.num =  0
# out.num =  -0.25339181019454315
# self.gradient before =  0.0
# self.gradient after =  -0.25880730032549953
# out.gradient =  -0.25880730032549953
#
#
# Multiplication
# -----------------
# self.num =  0.5
# other.num =  -0.5067836203890863
# out.num =  -0.25339181019454315
# self.gradient before =  0.0
# self.gradient after =  0.1311593006420822
# out.gradient =  -0.25880730032549953
#
#
# Multiplication
# -----------------
# self.num =  -0.3
# other.num =  0.9971624445641505
# out.num =  -0.29914873336924513
# self.gradient before =  0.0
# self.gradient after =  -0.2580729202636234
# out.gradient =  -0.25880730032549953
#
#
# Multiplication
# -----------------
# self.num =  0.8
# other.num =  0.19813295758782123
# out.num =  0.158506366070257
# self.gradient before =  0.0
# self.gradient after =  -0.05127825585881071
# out.gradient =  -0.25880730032549953
#
#
# Multiplication
# -----------------
# self.num =  -0.6733734835107714
# other.num =  0.8058065663740552
# out.num =  -0.5426087746351512
# self.gradient before =  0.0
# self.gradient after =  -0.2594727404742262
# out.gradient =  -0.3220037553699693
#
#
# Addition
# -----------------
# self.num =  0.3093783184555032
# other.num =  -0.9827518019662747
# out.num =  -0.6733734835107714
# self.gradient before =  0.0
# self.gradient after =  -0.2594727404742262
# out.gradient =  -0.2594727404742262
#
#
# Addition
# -----------------
# self.num =  0.08356772484709746
# other.num =  0.22581059360840572
# out.num =  0.3093783184555032
# self.gradient before =  0.0
# self.gradient after =  -0.2594727404742262
# out.gradient =  -0.2594727404742262
#
#
# Addition
# -----------------
# self.num =  -0.215798148083841
# other.num =  0.29936587293093847
# out.num =  0.08356772484709746
# self.gradient before =  0.0
# self.gradient after =  -0.2594727404742262
# out.gradient =  -0.2594727404742262
#
#
# Addition
# -----------------
# self.num =  -0.215798148083841
# other.num =  0
# out.num =  -0.215798148083841
# self.gradient before =  0.0
# self.gradient after =  -0.2594727404742262
# out.gradient =  -0.2594727404742262
#
#
# Multiplication
# -----------------
# self.num =  0.5
# other.num =  -0.431596296167682
# out.num =  -0.215798148083841
# self.gradient before =  0.1311593006420822
# self.gradient after =  0.24314677438723642
# out.gradient =  -0.2594727404742262
#
#
# Multiplication
# -----------------
# self.num =  -0.3
# other.num =  -0.9978862431031283
# out.num =  0.29936587293093847
# self.gradient before =  -0.2580729202636234
# self.gradient after =  0.000851357915875206
# out.gradient =  -0.2594727404742262
#
#
# Multiplication
# -----------------
# self.num =  0.8
# other.num =  0.2822632420105071
# out.num =  0.22581059360840572
# self.gradient before =  -0.05127825585881071
# self.gradient after =  -0.12451787279841672
# out.gradient =  -0.2594727404742262
#
#
# Multiplication
# -----------------
# self.num =  1.1506587383933327
# other.num =  0.610700255710277
# out.num =  0.7027075857720729
# self.gradient before =  0.0
# self.gradient after =  -0.19664777574410972
# out.gradient =  -0.3220037553699693
#
#
# Addition
# -----------------
# self.num =  0.27251092939604293
# other.num =  0.8781478089972898
# out.num =  1.1506587383933327
# self.gradient before =  0.0
# self.gradient after =  -0.19664777574410972
# out.gradient =  -0.19664777574410972
#
#
# Addition
# -----------------
# self.num =  -0.21442073538987824
# other.num =  0.48693166478592115
# out.num =  0.27251092939604293
# self.gradient before =  0.0
# self.gradient after =  -0.19664777574410972
# out.gradient =  -0.19664777574410972
#
#
# Addition
# -----------------
# self.num =  -0.19825066688807147
# other.num =  -0.016170068501806776
# out.num =  -0.21442073538987824
# self.gradient before =  0.0
# self.gradient after =  -0.19664777574410972
# out.gradient =  -0.19664777574410972
#
#
# Addition
# -----------------
# self.num =  -0.19825066688807147
# other.num =  0
# out.num =  -0.19825066688807147
# self.gradient before =  0.0
# self.gradient after =  -0.19664777574410972
# out.gradient =  -0.19664777574410972
#
#
# Multiplication
# -----------------
# self.num =  0.5
# other.num =  -0.39650133377614294
# out.num =  -0.19825066688807147
# self.gradient before =  0.24314677438723642
# self.gradient after =  0.3211178797538878
# out.gradient =  -0.19664777574410972
#
#
# Multiplication
# -----------------
# self.num =  -0.3
# other.num =  0.05390022833935593
# out.num =  -0.016170068501806776
# self.gradient before =  0.000851357915875206
# self.gradient after =  -0.009748002099158765
# out.gradient =  -0.19664777574410972
#
#
# Multiplication
# -----------------
# self.num =  0.8
# other.num =  0.6086645809824014
# out.num =  0.48693166478592115
# self.gradient before =  -0.12451787279841672
# self.gradient after =  -0.24421040882282652
# out.gradient =  -0.19664777574410972
#
#
# Multiplication
# -----------------
# self.num =  -0.5927542254228391
# other.num =  0.34401734704639786
# out.num =  -0.2039177360805076
# self.gradient before =  0.0
# self.gradient after =  0.34401734704639786
# out.gradient =  1.0
#
#
# Addition
# -----------------
# self.num =  -0.6573934924631781
# other.num =  0.06463926704033907
# out.num =  -0.5927542254228391
# self.gradient before =  0.0
# self.gradient after =  0.34401734704639786
# out.gradient =  0.34401734704639786
#
#
# Addition
# -----------------
# self.num =  -0.6800526642942302
# other.num =  0.022659171831052018
# out.num =  -0.6573934924631781
# self.gradient before =  0.0
# self.gradient after =  0.34401734704639786
# out.gradient =  0.34401734704639786
#
#
# Addition
# -----------------
# self.num =  -0.9230307941188736
# other.num =  0.24297812982464334
# out.num =  -0.6800526642942302
# self.gradient before =  0.0
# self.gradient after =  0.34401734704639786
# out.gradient =  0.34401734704639786
#
#
# Addition
# -----------------
# self.num =  -0.9230307941188736
# other.num =  0
# out.num =  -0.9230307941188736
# self.gradient before =  0.0
# self.gradient after =  0.34401734704639786
# out.gradient =  0.34401734704639786
#
#
# Multiplication
# -----------------
# self.num =  -1.058383819802912
# other.num =  0.8721134779731956
# out.num =  -0.9230307941188736
# self.gradient before =  -0.25880730032549953
# self.gradient after =  0.04121486469024638
# out.gradient =  0.34401734704639786
#
#
# Addition
# -----------------
# self.num =  -0.3940341774935312
# other.num =  -0.6643496423093809
# out.num =  -1.058383819802912
# self.gradient before =  -0.25880730032549953
# self.gradient after =  -0.21759243563525316
# out.gradient =  0.04121486469024638
#
#
# Addition
# -----------------
# self.num =  -0.5525405435637882
# other.num =  0.158506366070257
# out.num =  -0.3940341774935312
# self.gradient before =  -0.25880730032549953
# self.gradient after =  -0.4763997359607527
# out.gradient =  -0.21759243563525316
#
#
# Addition
# -----------------
# self.num =  -0.25339181019454315
# other.num =  -0.29914873336924513
# out.num =  -0.5525405435637882
# self.gradient before =  -0.25880730032549953
# self.gradient after =  -0.7352070362862522
# out.gradient =  -0.4763997359607527
#
#
# Addition
# -----------------
# self.num =  -0.25339181019454315
# other.num =  0
# out.num =  -0.25339181019454315
# self.gradient before =  -0.25880730032549953
# self.gradient after =  -0.9940143366117518
# out.gradient =  -0.7352070362862522
#
#
# Multiplication
# -----------------
# self.num =  0.5
# other.num =  -0.5067836203890863
# out.num =  -0.25339181019454315
# self.gradient before =  0.3211178797538878
# self.gradient after =  0.8248680639806472
# out.gradient =  -0.9940143366117518
#
#
# Multiplication
# -----------------
# self.num =  -0.3
# other.num =  0.9971624445641505
# out.num =  -0.29914873336924513
# self.gradient before =  -0.009748002099158765
# self.gradient after =  -0.742868847663122
# out.gradient =  -0.7352070362862522
#
#
# Multiplication
# -----------------
# self.num =  0.8
# other.num =  0.19813295758782123
# out.num =  0.158506366070257
# self.gradient before =  -0.24421040882282652
# self.gradient after =  -0.33860089750278755
# out.gradient =  -0.4763997359607527
#
#
# Multiplication
# -----------------
# self.num =  -0.6733734835107714
# other.num =  -0.3608370923040016
# out.num =  0.24297812982464334
# self.gradient before =  -0.2594727404742262
# self.gradient after =  -0.383606959684585
# out.gradient =  0.34401734704639786
#
#
# Addition
# -----------------
# self.num =  0.3093783184555032
# other.num =  -0.9827518019662747
# out.num =  -0.6733734835107714
# self.gradient before =  -0.2594727404742262
# self.gradient after =  -0.6430797001588112
# out.gradient =  -0.383606959684585
#
#
# Addition
# -----------------
# self.num =  0.08356772484709746
# other.num =  0.22581059360840572
# out.num =  0.3093783184555032
# self.gradient before =  -0.2594727404742262
# self.gradient after =  -0.9025524406330374
# out.gradient =  -0.6430797001588112
#
#
# Addition
# -----------------
# self.num =  -0.215798148083841
# other.num =  0.29936587293093847
# out.num =  0.08356772484709746
# self.gradient before =  -0.2594727404742262
# self.gradient after =  -1.1620251811072637
# out.gradient =  -0.9025524406330374
#
#
# Addition
# -----------------
# self.num =  -0.215798148083841
# other.num =  0
# out.num =  -0.215798148083841
# self.gradient before =  -0.2594727404742262
# self.gradient after =  -1.4214979215814898
# out.gradient =  -1.1620251811072637
#
#
# Multiplication
# -----------------
# self.num =  0.5
# other.num =  -0.431596296167682
# out.num =  -0.215798148083841
# self.gradient before =  0.8248680639806472
# self.gradient after =  1.4383813019452762
# out.gradient =  -1.4214979215814898
#
#
# Multiplication
# -----------------
# self.num =  -0.3
# other.num =  -0.9978862431031283
# out.num =  0.29936587293093847
# self.gradient before =  -0.742868847663122
# self.gradient after =  0.41670009470323777
# out.gradient =  -1.1620251811072637
#
#
# Multiplication
# -----------------
# self.num =  0.8
# other.num =  0.2822632420105071
# out.num =  0.22581059360840572
# self.gradient before =  -0.33860089750278755
# self.gradient after =  -0.5933582754803645
# out.gradient =  -0.9025524406330374
#
#
# Multiplication
# -----------------
# self.num =  1.1506587383933327
# other.num =  0.019692347587514147
# out.num =  0.022659171831052018
# self.gradient before =  -0.19664777574410972
# self.gradient after =  -0.18987326656993755
# out.gradient =  0.34401734704639786
#
#
# Addition
# -----------------
# self.num =  0.27251092939604293
# other.num =  0.8781478089972898
# out.num =  1.1506587383933327
# self.gradient before =  -0.19664777574410972
# self.gradient after =  -0.38652104231404727
# out.gradient =  -0.18987326656993755
#
#
# Addition
# -----------------
# self.num =  -0.21442073538987824
# other.num =  0.48693166478592115
# out.num =  0.27251092939604293
# self.gradient before =  -0.19664777574410972
# self.gradient after =  -0.583168818058157
# out.gradient =  -0.38652104231404727
#
#
# Addition
# -----------------
# self.num =  -0.19825066688807147
# other.num =  -0.016170068501806776
# out.num =  -0.21442073538987824
# self.gradient before =  -0.19664777574410972
# self.gradient after =  -0.7798165938022668
# out.gradient =  -0.583168818058157
#
#
# Addition
# -----------------
# self.num =  -0.19825066688807147
# other.num =  0
# out.num =  -0.19825066688807147
# self.gradient before =  -0.19664777574410972
# self.gradient after =  -0.9764643695463765
# out.gradient =  -0.7798165938022668
#
#
# Multiplication
# -----------------
# self.num =  0.5
# other.num =  -0.39650133377614294
# out.num =  -0.19825066688807147
# self.gradient before =  1.4383813019452762
# self.gradient after =  1.825550726855295
# out.gradient =  -0.9764643695463765
#
#
# Multiplication
# -----------------
# self.num =  -0.3
# other.num =  0.05390022833935593
# out.num =  -0.016170068501806776
# self.gradient before =  0.41670009470323777
# self.gradient after =  0.3746678022344768
# out.gradient =  -0.7798165938022668
#
#
# Multiplication
# -----------------
# self.num =  0.8
# other.num =  0.6086645809824014
# out.num =  0.48693166478592115
# self.gradient before =  -0.5933582754803645
# self.gradient after =  -0.9483124797657349
# out.gradient =  -0.583168818058157
#
#
# Multiplication
# -----------------
# self.num =  -0.005981092601169358
# other.num =  -0.39019396432140807
# out.num =  0.002333786233023714
# self.gradient before =  0.0
# self.gradient after =  -0.39019396432140807
# out.gradient =  1.0
#
#
# Addition
# -----------------
# self.num =  0.3694186706851788
# other.num =  -0.37539976328634816
# out.num =  -0.005981092601169358
# self.gradient before =  0.0
# self.gradient after =  -0.39019396432140807
# out.gradient =  -0.39019396432140807
#
#
# Addition
# -----------------
# self.num =  0.27037598935611257
# other.num =  0.09904268132906623
# out.num =  0.3694186706851788
# self.gradient before =  0.0
# self.gradient after =  -0.39019396432140807
# out.gradient =  -0.39019396432140807
#
#
# Addition
# -----------------
# self.num =  0.6006569114329924
# other.num =  -0.3302809220768798
# out.num =  0.27037598935611257
# self.gradient before =  0.0
# self.gradient after =  -0.39019396432140807
# out.gradient =  -0.39019396432140807
#
#
# Addition
# -----------------
# self.num =  0.6006569114329924
# other.num =  0
# out.num =  0.6006569114329924
# self.gradient before =  0.0
# self.gradient after =  -0.39019396432140807
# out.gradient =  -0.39019396432140807
#
#
# Multiplication
# -----------------
# self.num =  -1.058383819802912
# other.num =  -0.5675227646099543
# out.num =  0.6006569114329924
# self.gradient before =  0.04121486469024638
# self.gradient after =  0.26265882205604973
# out.gradient =  -0.39019396432140807
#
#
# Addition
# -----------------
# self.num =  -0.3940341774935312
# other.num =  -0.6643496423093809
# out.num =  -1.058383819802912
# self.gradient before =  -0.21759243563525316
# self.gradient after =  0.04506638642079658
# out.gradient =  0.26265882205604973
#
#
# Addition
# -----------------
# self.num =  -0.5525405435637882
# other.num =  0.158506366070257
# out.num =  -0.3940341774935312
# self.gradient before =  -0.4763997359607527
# self.gradient after =  -0.4313333495399561
# out.gradient =  0.04506638642079658
#
#
# Addition
# -----------------
# self.num =  -0.25339181019454315
# other.num =  -0.29914873336924513
# out.num =  -0.5525405435637882
# self.gradient before =  -0.7352070362862522
# self.gradient after =  -1.1665403858262082
# out.gradient =  -0.4313333495399561
#
#
# Addition
# -----------------
# self.num =  -0.25339181019454315
# other.num =  0
# out.num =  -0.25339181019454315
# self.gradient before =  -0.9940143366117518
# self.gradient after =  -2.16055472243796
# out.gradient =  -1.1665403858262082
#
#
# Multiplication
# -----------------
# self.num =  0.5
# other.num =  -0.5067836203890863
# out.num =  -0.25339181019454315
# self.gradient before =  1.825550726855295
# self.gradient after =  2.920484471141142
# out.gradient =  -2.16055472243796
# Multiplication
# -----------------
# self.num =  -0.3
# other.num =  0.9971624445641505
# out.num =  -0.29914873336924513
# self.gradient before =  0.3746678022344768
# self.gradient after =  -0.7885624605787923
# out.gradient =  -1.1665403858262082
#
#
# Multiplication
# -----------------
# self.num =  0.8
# other.num =  0.19813295758782123
# out.num =  0.158506366070257
# self.gradient before =  -0.9483124797657349
# self.gradient after =  -1.0337738320163479
# out.gradient =  -0.4313333495399561
#
#
# Multiplication
# -----------------
# self.num =  -0.6733734835107714
# other.num =  0.490486973670083
# out.num =  -0.3302809220768798
# self.gradient before =  -0.383606959684585
# self.gradient after =  -0.5749920163889248
# out.gradient =  -0.39019396432140807
#
#
# Addition
# -----------------
# self.num =  0.3093783184555032
# other.num =  -0.9827518019662747
# out.num =  -0.6733734835107714
# self.gradient before =  -0.6430797001588112
# self.gradient after =  -1.218071716547736
# out.gradient =  -0.5749920163889248
#
#
# Addition
# -----------------
# self.num =  0.08356772484709746
# other.num =  0.22581059360840572
# out.num =  0.3093783184555032
# self.gradient before =  -0.9025524406330374
# self.gradient after =  -2.1206241571807736
# out.gradient =  -1.218071716547736
#
#
# Addition
# -----------------
# self.num =  -0.215798148083841
# other.num =  0.29936587293093847
# out.num =  0.08356772484709746
# self.gradient before =  -1.1620251811072637
# self.gradient after =  -3.2826493382880373
# out.gradient =  -2.1206241571807736
#
#
# Addition
# -----------------
# self.num =  -0.215798148083841
# other.num =  0
# out.num =  -0.215798148083841
# self.gradient before =  -1.4214979215814898
# self.gradient after =  -4.7041472598695275
# out.gradient =  -3.2826493382880373
#
#
# Multiplication
# -----------------
# self.num =  0.5
# other.num =  -0.431596296167682
# out.num =  -0.215798148083841
# self.gradient before =  2.920484471141142
# self.gradient after =  4.950777005128181
# out.gradient =  -4.7041472598695275
#
#
# Multiplication
# -----------------
# self.num =  -0.3
# other.num =  -0.9978862431031283
# out.num =  0.29936587293093847
# self.gradient before =  -0.7885624605787923
# self.gradient after =  2.4871481550304275
# out.gradient =  -3.2826493382880373
#
#
# Multiplication
# -----------------
# self.num =  0.8
# other.num =  0.2822632420105071
# out.num =  0.22581059360840572
# self.gradient before =  -1.0337738320163479
# self.gradient after =  -1.6323480817079923
# out.gradient =  -2.1206241571807736
#
#
# Multiplication
# -----------------
# self.num =  1.1506587383933327
# other.num =  0.08607476571842643
# out.num =  0.09904268132906623
# self.gradient before =  -0.18987326656993755
# self.gradient after =  -0.22345912063364679
# out.gradient =  -0.39019396432140807
#
#
# Addition
# -----------------
# self.num =  0.27251092939604293
# other.num =  0.8781478089972898
# out.num =  1.1506587383933327
# self.gradient before =  -0.38652104231404727
# self.gradient after =  -0.6099801629476941
# out.gradient =  -0.22345912063364679
#
#
# Addition
# -----------------
# self.num =  -0.21442073538987824
# other.num =  0.48693166478592115
# out.num =  0.27251092939604293
# self.gradient before =  -0.583168818058157
# self.gradient after =  -1.193148981005851
# out.gradient =  -0.6099801629476941
#
#
# Addition
# -----------------
# self.num =  -0.19825066688807147
# other.num =  -0.016170068501806776
# out.num =  -0.21442073538987824
# self.gradient before =  -0.7798165938022668
# self.gradient after =  -1.9729655748081179
# out.gradient =  -1.193148981005851
#
#
# Addition
# -----------------
# self.num =  -0.19825066688807147
# other.num =  0
# out.num =  -0.19825066688807147
# self.gradient before =  -0.9764643695463765
# self.gradient after =  -2.9494299443544945
# out.gradient =  -1.9729655748081179
#
#
# Multiplication
# -----------------
# self.num =  0.5
# other.num =  -0.39650133377614294
# out.num =  -0.19825066688807147
# self.gradient before =  4.950777005128181
# self.gradient after =  6.120229911944033
# out.gradient =  -2.9494299443544945
#
#
# Multiplication
# -----------------
# self.num =  -0.3
# other.num =  0.05390022833935593
# out.num =  -0.016170068501806776
# self.gradient before =  2.4871481550304275
# self.gradient after =  2.3808048600425815
# out.gradient =  -1.9729655748081179
#
#
# Multiplication
# -----------------
# self.num =  0.8
# other.num =  0.6086645809824014
# out.num =  0.48693166478592115
# self.gradient before =  -1.6323480817079923
# self.gradient after =  -2.358575606281498
# out.gradient =  -1.193148981005851
#
#
# Multiplication
# -----------------
# self.num =  -0.27988190624147447
# other.num =  0.09085473748815698
# out.num =  -0.025428597119254128
# self.gradient before =  0.0
# self.gradient after =  0.09085473748815698
# out.gradient =  1.0
#
#
# Addition
# -----------------
# self.num =  -0.752310146424865
# other.num =  0.4724282401833906
# out.num =  -0.27988190624147447
# self.gradient before =  0.0
# self.gradient after =  0.09085473748815698
# out.gradient =  0.09085473748815698
#
#
# Addition
# -----------------
# self.num =  -0.20767145286716238
# other.num =  -0.5446386935577027
# out.num =  -0.752310146424865
# self.gradient before =  0.0
# self.gradient after =  0.09085473748815698
# out.gradient =  0.09085473748815698
#
#
# Addition
# -----------------
# self.num =  -0.7566435281875568
# other.num =  0.5489720753203944
# out.num =  -0.20767145286716238
# self.gradient before =  0.0
# self.gradient after =  0.09085473748815698
# out.gradient =  0.09085473748815698
#
#
# Addition
# -----------------
# self.num =  -0.7566435281875568
# other.num =  0
# out.num =  -0.7566435281875568
# self.gradient before =  0.0
# self.gradient after =  0.09085473748815698
# out.gradient =  0.09085473748815698
#
#
# Multiplication
# -----------------
# self.num =  -1.058383819802912
# other.num =  0.7149046631575073
# out.num =  -0.7566435281875568
# self.gradient before =  0.26265882205604973
# self.gradient after =  0.3276112975562844
# out.gradient =  0.09085473748815698
#
#
# Addition
# -----------------
# self.num =  -0.3940341774935312
# other.num =  -0.6643496423093809
# out.num =  -1.058383819802912
# self.gradient before =  0.04506638642079658
# self.gradient after =  0.37267768397708095
# out.gradient =  0.3276112975562844
#
#
# Addition
# -----------------
# self.num =  -0.5525405435637882
# other.num =  0.158506366070257
# out.num =  -0.3940341774935312
# self.gradient before =  -0.4313333495399561
# self.gradient after =  -0.05865566556287516
# out.gradient =  0.37267768397708095
#
#
# Addition
# -----------------
# self.num =  -0.25339181019454315
# other.num =  -0.29914873336924513
# out.num =  -0.5525405435637882
# self.gradient before =  -1.1665403858262082
# self.gradient after =  -1.2251960513890834
# out.gradient =  -0.05865566556287516
#
#
# Addition
# -----------------
# self.num =  -0.25339181019454315
# other.num =  0
# out.num =  -0.25339181019454315
# self.gradient before =  -2.16055472243796
# self.gradient after =  -3.385750773827043
# out.gradient =  -1.2251960513890834
#
#
# Multiplication
# -----------------
# self.num =  0.5
# other.num =  -0.5067836203890863
# out.num =  -0.25339181019454315
# self.gradient before =  6.120229911944033
# self.gradient after =  7.836072946839253
# out.gradient =  -3.385750773827043
#
#
# Multiplication
# -----------------
# self.num =  -0.3
# other.num =  0.9971624445641505
# out.num =  -0.29914873336924513
# self.gradient before =  2.3808048600425815
# self.gradient after =  1.1590853703690986
# out.gradient =  -1.2251960513890834
#
#
# Multiplication
# -----------------
# self.num =  0.8
# other.num =  0.19813295758782123
# out.num =  0.158506366070257
# self.gradient before =  -2.358575606281498
# self.gradient after =  -2.3701972267787523
# out.gradient =  -0.05865566556287516
#
#
# Multiplication
# -----------------
# self.num =  -0.6733734835107714
# other.num =  -0.8152564494494428
# out.num =  0.5489720753203944
# self.gradient before =  -0.5749920163889248
# self.gradient after =  -0.6490619270891809
# out.gradient =  0.09085473748815698
#
#
# Addition
# -----------------
# self.num =  0.3093783184555032
# other.num =  -0.9827518019662747
# out.num =  -0.6733734835107714
# self.gradient before =  -1.218071716547736
# self.gradient after =  -1.8671336436369168
# out.gradient =  -0.6490619270891809
#
#
# Addition
# -----------------
# self.num =  0.08356772484709746
# other.num =  0.22581059360840572
# out.num =  0.3093783184555032
# self.gradient before =  -2.1206241571807736
# self.gradient after =  -3.9877578008176906
# out.gradient =  -1.8671336436369168
#
#
# Addition
# -----------------
# self.num =  -0.215798148083841
# other.num =  0.29936587293093847
# out.num =  0.08356772484709746
# self.gradient before =  -3.2826493382880373
# self.gradient after =  -7.270407139105728
# out.gradient =  -3.9877578008176906
#
#
# Addition
# -----------------
# self.num =  -0.215798148083841
# other.num =  0
# out.num =  -0.215798148083841
# self.gradient before =  -4.7041472598695275
# self.gradient after =  -11.974554398975256
# out.gradient =  -7.270407139105728
#
#
# Multiplication
# -----------------
# self.num =  0.5
# other.num =  -0.431596296167682
# out.num =  -0.215798148083841
# self.gradient before =  7.836072946839253
# self.gradient after =  13.004246273695397
# out.gradient =  -11.974554398975256
#
#
# Multiplication
# -----------------
# self.num =  -0.3
# other.num =  -0.9978862431031283
# out.num =  0.29936587293093847
# self.gradient before =  1.1590853703690986
# self.gradient after =  8.414124636241477
# out.gradient =  -7.270407139105728
#
#
# Multiplication
# -----------------
# self.num =  0.8
# other.num =  0.2822632420105071
# out.num =  0.22581059360840572
# self.gradient before =  -2.3701972267787523
# self.gradient after =  -3.495794671990244
# out.gradient =  -3.9877578008176906
#
#
# Multiplication
# -----------------
# self.num =  1.1506587383933327
# other.num =  -0.4733277342665323
# out.num =  -0.5446386935577027
# self.gradient before =  -0.22345912063364679
# self.gradient after =  -0.26646318767629673
# out.gradient =  0.09085473748815698
#
#
# Addition
# -----------------
# self.num =  0.27251092939604293
# other.num =  0.8781478089972898
# out.num =  1.1506587383933327
# self.gradient before =  -0.6099801629476941
# self.gradient after =  -0.8764433506239908
# out.gradient =  -0.26646318767629673
#
#
# Addition
# -----------------
# self.num =  -0.21442073538987824
# other.num =  0.48693166478592115
# out.num =  0.27251092939604293
# self.gradient before =  -1.193148981005851
# self.gradient after =  -2.069592331629842
# out.gradient =  -0.8764433506239908
#
#
# Addition
# -----------------
# self.num =  -0.19825066688807147
# other.num =  -0.016170068501806776
# out.num =  -0.21442073538987824
# self.gradient before =  -1.9729655748081179
# self.gradient after =  -4.04255790643796
# out.gradient =  -2.069592331629842
#
#
# Addition
# -----------------
# self.num =  -0.19825066688807147
# other.num =  0
# out.num =  -0.19825066688807147
# self.gradient before =  -2.9494299443544945
# self.gradient after =  -6.991987850792454
# out.gradient =  -4.04255790643796
#
#
# Multiplication
# -----------------
# self.num =  0.5
# other.num =  -0.39650133377614294
# out.num =  -0.19825066688807147
# self.gradient before =  13.004246273695397
# self.gradient after =  15.776578782281192
# out.gradient =  -6.991987850792454
#
#
# Multiplication
# -----------------
# self.num =  -0.3
# other.num =  0.05390022833935593
# out.num =  -0.016170068501806776
# self.gradient before =  8.414124636241477
# self.gradient after =  8.196229842009402
# out.gradient =  -4.04255790643796
#
#
# Multiplication
# -----------------
# self.num =  0.8
# other.num =  0.6086645809824014
# out.num =  0.48693166478592115
# self.gradient before =  -3.495794671990244
# self.gradient after =  -4.755482221326113
# out.gradient =  -2.069592331629842

# %%
# Draw computational graph

dot = draw_dot(inputs[0])
display(SVG(dot.pipe(format='svg')))
dot.render(filename='graph_output', format='svg', cleanup=False)
# Out:
# 'graph_output.svg'

# %%
conda install pytorch torchvision torchaudio cpuonly -c pytorch
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\96898\anaconda3
#
#   added / updated specs:
#     - cpuonly
#     - pytorch
#     - torchaudio
#
# Note: you may need to restart the kernel to use updated packages.    - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#     cpuonly-2.0                |                0           2 KB  pytorch
#     libjpeg-turbo-2.0.0        |       h196d8e1_0         618 KB
#     libuv-1.44.2               |       h2bbff1b_0         288 KB
#     pytorch-2.3.0              |      py3.9_cpu_0       138.3 MB  pytorch
#     pytorch-mutex-1.0          |              cpu           3 KB  pytorch
#     torchaudio-2.3.0           |         py39_cpu         5.7 MB  pytorch
#     torchvision-0.18.0         |         py39_cpu         6.5 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:       151.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   cpuonly            pytorch/noarch::cpuonly-2.0-0
#   libjpeg-turbo      pkgs/main/win-64::libjpeg-turbo-2.0.0-h196d8e1_0
#   libuv              pkgs/main/win-64::libuv-1.44.2-h2bbff1b_0
#   pytorch            pytorch/win-64::pytorch-2.3.0-py3.9_cpu_0
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cpu
#   torchaudio         pytorch/win-64::torchaudio-2.3.0-py39_cpu
#   torchvision        pytorch/win-64::torchvision-0.18.0-py39_cpu
#
#
#
# Downloading and Extracting Packages
#
# torchvision-0.18.0   | 6.5 MB    |            |   0%
# torchvision-0.18.0   | 6.5 MB    |            |   0%
# torchvision-0.18.0   | 6.5 MB    | 7          |   7%
# torchvision-0.18.0   | 6.5 MB    | #5         |  15%
# torchvision-0.18.0   | 6.5 MB    | ##5        |  26%
# torchvision-0.18.0   | 6.5 MB    | ###8       |  38%
# torchvision-0.18.0   | 6.5 MB    | #####2     |  52%
# torchvision-0.18.0   | 6.5 MB    | ######5    |  66%
# torchvision-0.18.0   | 6.5 MB    | ########6  |  86%
# torchvision-0.18.0   | 6.5 MB    | ########## | 100%
#
# cpuonly-2.0          | 2 KB      |            |   0%
# cpuonly-2.0          | 2 KB      | ########## | 100%
#
# libjpeg-turbo-2.0.0  | 618 KB    |            |   0%
# libjpeg-turbo-2.0.0  | 618 KB    | 2          |   3%
# libjpeg-turbo-2.0.0  | 618 KB    | #####4     |  54%
# libjpeg-turbo-2.0.0  | 618 KB    | ########## | 100%
# libjpeg-turbo-2.0.0  | 618 KB    | ########## | 100%
#
# torchaudio-2.3.0     | 5.7 MB    |            |   0%
# torchaudio-2.3.0     | 5.7 MB    | 2          |   3%
# torchaudio-2.3.0     | 5.7 MB    | ##         |  21%
# torchaudio-2.3.0     | 5.7 MB    | ####8      |  49%
# torchaudio-2.3.0     | 5.7 MB    | #######3   |  73%
# torchaudio-2.3.0     | 5.7 MB    | #########3 |  94%
# torchaudio-2.3.0     | 5.7 MB    | ########## | 100%
#
# pytorch-2.3.0        | 138.3 MB  |            |   0%
# pytorch-2.3.0        | 138.3 MB  |            |   0%
# pytorch-2.3.0        | 138.3 MB  | 1          |   2%
# pytorch-2.3.0        | 138.3 MB  | 2          |   2%
# pytorch-2.3.0        | 138.3 MB  | 4          |   4%
# pytorch-2.3.0        | 138.3 MB  | 5          |   5%
# pytorch-2.3.0        | 138.3 MB  | 6          |   7%
# pytorch-2.3.0        | 138.3 MB  | 8          |   8%
# pytorch-2.3.0        | 138.3 MB  | #          |  10%
# pytorch-2.3.0        | 138.3 MB  | #1         |  12%
# pytorch-2.3.0        | 138.3 MB  | #3         |  14%
# pytorch-2.3.0        | 138.3 MB  | #5         |  15%
# pytorch-2.3.0        | 138.3 MB  | #7         |  17%
# pytorch-2.3.0        | 138.3 MB  | #9         |  20%
# pytorch-2.3.0        | 138.3 MB  | ##1        |  22%
# pytorch-2.3.0        | 138.3 MB  | ##4        |  24%
# pytorch-2.3.0        | 138.3 MB  | ##6        |  27%
# pytorch-2.3.0        | 138.3 MB  | ##8        |  29%
# pytorch-2.3.0        | 138.3 MB  | ###1       |  31%
# pytorch-2.3.0        | 138.3 MB  | ###3       |  33%
# pytorch-2.3.0        | 138.3 MB  | ###4       |  35%
# pytorch-2.3.0        | 138.3 MB  | ###6       |  36%
# pytorch-2.3.0        | 138.3 MB  | ###7       |  37%
# pytorch-2.3.0        | 138.3 MB  | ###8       |  39%
# pytorch-2.3.0        | 138.3 MB  | ###9       |  40%
# pytorch-2.3.0        | 138.3 MB  | ####1      |  42%
# pytorch-2.3.0        | 138.3 MB  | ####3      |  43%
# pytorch-2.3.0        | 138.3 MB  | ####5      |  45%
# pytorch-2.3.0        | 138.3 MB  | ####7      |  47%
# pytorch-2.3.0        | 138.3 MB  | ####9      |  50%
# pytorch-2.3.0        | 138.3 MB  | #####1     |  52%
# pytorch-2.3.0        | 138.3 MB  | #####3     |  53%
# pytorch-2.3.0        | 138.3 MB  | #####5     |  56%
# pytorch-2.3.0        | 138.3 MB  | #####7     |  58%
# pytorch-2.3.0        | 138.3 MB  | ######     |  60%
# pytorch-2.3.0        | 138.3 MB  | ######2    |  62%
# pytorch-2.3.0        | 138.3 MB  | ######3    |  64%
# pytorch-2.3.0        | 138.3 MB  | ######5    |  65%
# pytorch-2.3.0        | 138.3 MB  | ######8    |  68%
# pytorch-2.3.0        | 138.3 MB  | #######    |  70%
# pytorch-2.3.0        | 138.3 MB  | #######1   |  72%
# pytorch-2.3.0        | 138.3 MB  | #######3   |  73%
# pytorch-2.3.0        | 138.3 MB  | #######6   |  76%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  77%
# pytorch-2.3.0        | 138.3 MB  | #######7   |  78%
# pytorch-2.3.0        | 138.3 MB  | #######8   |  79%
# pytorch-2.3.0        | 138.3 MB  | #######9   |  79%
# pytorch-2.3.0        | 138.3 MB  | ########   |  80%
# pytorch-2.3.0        | 138.3 MB  | ########   |  80%
# pytorch-2.3.0        | 138.3 MB  | ########   |  81%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  81%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  81%
# pytorch-2.3.0        | 138.3 MB  | ########1  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  82%
# pytorch-2.3.0        | 138.3 MB  | ########2  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  83%
# pytorch-2.3.0        | 138.3 MB  | ########3  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########4  |  84%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  85%
# pytorch-2.3.0        | 138.3 MB  | ########5  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########6  |  86%
# pytorch-2.3.0        | 138.3 MB  | ########7  |  87%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  88%
# pytorch-2.3.0        | 138.3 MB  | ########8  |  89%
# pytorch-2.3.0        | 138.3 MB  | #########  |  90%
# pytorch-2.3.0        | 138.3 MB  | #########1 |  91%
# pytorch-2.3.0        | 138.3 MB  | #########2 |  92%
# pytorch-2.3.0        | 138.3 MB  | #########4 |  94%
# pytorch-2.3.0        | 138.3 MB  | #########5 |  95%
# pytorch-2.3.0        | 138.3 MB  | #########6 |  96%
# pytorch-2.3.0        | 138.3 MB  | #########8 |  99%
# pytorch-2.3.0        | 138.3 MB  | ########## | 100%
# pytorch-2.3.0        | 138.3 MB  | ########## | 100%
#
# libuv-1.44.2         | 288 KB    |            |   0%
# libuv-1.44.2         | 288 KB    | ##7        |  28%
# libuv-1.44.2         | 288 KB    | ########## | 100%
# libuv-1.44.2         | 288 KB    | ########## | 100%
#
# pytorch-mutex-1.0    | 3 KB      |            |   0%
# pytorch-mutex-1.0    | 3 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
# Define the MLP architecture
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        # Define layers
        self.fc1 = nn.Linear(3, 3, bias=True)  # First layer: 3 inputs, 3 neurons
        self.fc2 = nn.Linear(3, 4, bias=True)  # Second layer: 3 neurons, 4 neurons
        self.fc3 = nn.Linear(4, 1, bias=True)  # Third layer: 4 neurons, 1 output

    def forward(self, x):
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        return x

# Initialize the model
model = MLP()

# Manually initialize weights and biases (to match your Micrograd model)
with torch.no_grad():
    model.fc1.weight = nn.Parameter(torch.tensor([[-0.5067836203890863, 0.9971624445641505, 0.19813295758782123], [-0.431596296167682, -0.9978862431031283, 0.2822632420105071],[-0.39650133377614294, 0.05390022833935593, 0.6086645809824014]]))
    model.fc1.bias = nn.Parameter(torch.tensor([-0.6643496423093809, -0.9827518019662747, 0.8781478089972898]))
    
    model.fc2.weight = nn.Parameter(torch.tensor([[0.8037400061627866, 0.8058065663740552, 0.610700255710277], [0.8721134779731956, -0.3608370923040016, 0.019692347587514147],[-0.5675227646099543, 0.490486973670083, 0.08607476571842643], [0.7149046631575073, -0.8152564494494428, -0.4733277342665323]]))
    model.fc2.bias = nn.Parameter(torch.tensor([-0.7438220413875365, 0.06463926704033907, -0.37539976328634816, 0.4724282401833906]))
    
    model.fc3.weight = nn.Parameter(torch.tensor([ [-0.3220037553699693, 0.34401734704639786, -0.39019396432140807, 0.09085473748815698]]))
    model.fc3.bias = nn.Parameter(torch.tensor([-0.6562667226077885]))

# Input data
inputs = torch.tensor([0.5, -0.3, 0.8], requires_grad=True)  # Requires gradient for backward pass

# Forward pass
outputs = model(inputs)

# Perform backward pass from output (assuming some scalar loss function)
loss = outputs.sum()  # Example loss function
loss.backward()

# Print gradients for each layer
print("Gradients for the input:")
print(inputs.grad)

print("Gradients for layer 1 weights:")
print(model.fc1.weight.grad)
print("Gradients for layer 1 biases:")
print(model.fc1.bias.grad)

print("Gradients for layer 2 weights:")
print(model.fc2.weight.grad)
print("Gradients for layer 2 biases:")
print(model.fc2.bias.grad)

print("Gradients for layer 3 weights:")
print(model.fc3.weight.grad)
print("Gradients for layer 3 biases:")
print(model.fc3.bias.grad)
# Out:
# Gradients for the input:
# tensor([ 0.2198,  0.9600, -0.2805])
# Gradients for layer 1 weights:
# tensor([[ 0.1638, -0.0983,  0.2621],
#         [-0.3245,  0.1947, -0.5192],
#         [-0.1332,  0.0799, -0.2132]])
# Gradients for layer 1 biases:
# tensor([ 0.3276, -0.6491, -0.2665])
# Gradients for layer 2 weights:
# tensor([[ 0.3408,  0.2168, -0.3705],
#         [-0.3641, -0.2317,  0.3958],
#         [ 0.4130,  0.2627, -0.4490],
#         [-0.0962, -0.0612,  0.1045]])
# Gradients for layer 2 biases:
# tensor([-0.3220,  0.3440, -0.3902,  0.0909])
# Gradients for layer 3 weights:
# tensor([[-1.4344, -0.5928, -0.0060, -0.2799]])
# Gradients for layer 3 biases:
# tensor([1.])
